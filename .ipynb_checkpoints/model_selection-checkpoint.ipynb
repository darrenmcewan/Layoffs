# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score, f1_score
import statsmodels.api as sm
import shap
from sklearn.feature_selection import SelectFromModel

from sklearn.naive_bayes import GaussianNB

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Load data and clean

# %%
df = pd.read_csv('Layoff.csv',encoding='cp1252')
df = df.drop(['Company', 'City', 'State', 'Effective Date', 'Closure_Layoff','Temporary_Permanent','Union','Region','County'], axis=1)
df['WARN Received Date'] = pd.to_datetime(df['WARN Received Date'])
df.head()
# Out:
#    Number of Workers WARN Received Date  \
# 0                 82         2020-04-02
# 1               1358         2020-04-07
# 2               1084         2020-04-14
# 3               1064         2020-04-20
# 4               1038         2020-04-20
#
#                                          Industry    Open     High       Low  \
# 0  Consumer Discretionary Select Sector SPDR Fund   93.15   95.480   91.9800
# 1  Consumer Discretionary Select Sector SPDR Fund  104.73  105.505  101.3700
# 2  Consumer Discretionary Select Sector SPDR Fund  108.88  111.030  108.3700
# 3  Consumer Discretionary Select Sector SPDR Fund  111.70  113.190  110.7701
# 4  Consumer Discretionary Select Sector SPDR Fund  111.70  113.190  110.7701
#
#     Close     Volume       CPI    PPI  ...   PPI_CPI  year  month  by_month  \
# 0   94.05  5998824.0  1.362005  200.5  ... -0.252575  2020      4   2020-04
# 1  101.59  7009093.0  1.362005  200.5  ... -0.252575  2020      4   2020-04
# 2  110.82  5744700.0  1.362005  200.5  ... -0.252575  2020      4   2020-04
# 3  110.96  3413066.0  1.362005  200.5  ... -0.252575  2020      4   2020-04
# 4  110.96  3413066.0  1.362005  200.5  ... -0.252575  2020      4   2020-04
#
#       Date  Hires_jolts  Quits_jolts  Layoffs_jolts  Hire_quite_jolts  \
# 0  2020-04          3.1          1.6            7.0               1.5
# 1  2020-04          3.1          1.6            7.0               1.5
# 2  2020-04          3.1          1.6            7.0               1.5
# 3  2020-04          3.1          1.6            7.0               1.5
# 4  2020-04          3.1          1.6            7.0               1.5
#
#    Job_seekers_ratio
# 0               4.89
# 1               4.89
# 2               4.89
# 3               4.89
# 4               4.89
#
# [5 rows x 29 columns]

# %%
quantiles = df['Number of Workers'].quantile([0.33, 0.66])
quantiles
# Out:
# 0.33    30.0
# 0.66    84.0
# Name: Number of Workers, dtype: float64

# %%
df['layoff_category'] = pd.cut(df['Number of Workers'], bins=[0, quantiles.iloc[0], quantiles.iloc[1], df['Number of Workers'].max()], labels=[1,2,3])

# %%
# Check for missing values
df = df[df['layoff_category'].notna()]
df.isna().sum()
# Out:
# Number of Workers       0
# WARN Received Date      0
# Industry                0
# Open                    0
# High                    0
# Low                     0
# Close                   0
# Volume                  0
# CPI                     0
# PPI                     0
# GDP                     0
# unemployment_rate       0
# job_nonfam              0
# job_IT                  0
# job_service             0
# job_retail              0
# job_education_health    0
# fed_rate                0
# PPI_chg                 0
# PPI_CPI                 0
# year                    0
# month                   0
# by_month                0
# Date                    0
# Hires_jolts             0
# Quits_jolts             0
# Layoffs_jolts           0
# Hire_quite_jolts        0
# Job_seekers_ratio       0
# layoff_category         0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'Number of Workers'}>,
#         <AxesSubplot: title={'center': 'WARN Received Date'}>,
#         <AxesSubplot: title={'center': 'Open'}>,
#         <AxesSubplot: title={'center': 'High'}>,
#         <AxesSubplot: title={'center': 'Low'}>],
#        [<AxesSubplot: title={'center': 'Close'}>,
#         <AxesSubplot: title={'center': 'Volume'}>,
#         <AxesSubplot: title={'center': 'CPI'}>,
#         <AxesSubplot: title={'center': 'PPI'}>,
#         <AxesSubplot: title={'center': 'GDP'}>],
#        [<AxesSubplot: title={'center': 'unemployment_rate'}>,
#         <AxesSubplot: title={'center': 'job_nonfam'}>,
#         <AxesSubplot: title={'center': 'job_IT'}>,
#         <AxesSubplot: title={'center': 'job_service'}>,
#         <AxesSubplot: title={'center': 'job_retail'}>],
#        [<AxesSubplot: title={'center': 'job_education_health'}>,
#         <AxesSubplot: title={'center': 'fed_rate'}>,
#         <AxesSubplot: title={'center': 'PPI_chg'}>,
#         <AxesSubplot: title={'center': 'PPI_CPI'}>,
#         <AxesSubplot: title={'center': 'year'}>],
#        [<AxesSubplot: title={'center': 'month'}>,
#         <AxesSubplot: title={'center': 'Hires_jolts'}>,
#         <AxesSubplot: title={'center': 'Quits_jolts'}>,
#         <AxesSubplot: title={'center': 'Layoffs_jolts'}>,
#         <AxesSubplot: title={'center': 'Hire_quite_jolts'}>],
#        [<AxesSubplot: title={'center': 'Job_seekers_ratio'}>,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(15,15))    
sns.heatmap(df.corr(), annot=True, ax=ax)
# Out:
# <AxesSubplot: >

# %%
# Visualize the relationship between two numerical columns using a scatter plot
plt.scatter(df['GDP'], df['unemployment_rate'])
plt.xlabel('GDP')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
sortedDF = df.sort_values(by=['WARN Received Date'], ascending=True)
fig, ax = plt.subplots(figsize=(10, 10))
 
plt.plot(sortedDF['WARN Received Date'], sortedDF['Number of Workers'])
plt.xlabel('Layoff Date')
plt.ylabel('# of Employees affected')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df['Price Volatility'] = df['High'] - df['Low']

# %%
# One hot encode
df = pd.get_dummies(df, columns=['Industry'])

# %% [markdown]
# # ML Models

# %%
X = df.drop(["WARN Received Date", "Number of Workers", "layoff_category", "by_month","Date"], axis=1)
y = df["layoff_category"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1707)

# %% [markdown]
# ## MLR

# %%
MLR = LinearRegression().fit(X_train, y_train)
preds = MLR.predict(X_test)

# %%
print("R^2 : ", r2_score(y_test, preds))
print("MAE :", mean_absolute_error(y_test,preds))
print("RMSE:",np.sqrt(mean_squared_error(y_test, preds)))
# Out:
# R^2 :  0.04949846119129775
# MAE : 0.6749021988942409
# RMSE: 0.7920699708443948

# %% [markdown]
# ## SHAP

# %%
explainer = shap.Explainer(MLR.predict, X_train)
shap_values = explainer(X_test)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In [16], line 2
#       1 explainer = shap.Explainer(MLR.predict, X_train)
# ----> 2 shap_values = explainer(X_test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\explainers\_permutation.py:82, in Permutation.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      78 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      79              outputs=None, silent=False):
#      80     """ Explain the output of the model on the given arguments.
#      81     """
# ---> 82     return super().__call__(
#      83         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      84         outputs=outputs, silent=silent
#      85     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\explainers\_explainer.py:266, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264     feature_names = [[] for _ in range(len(args))]
#     265 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266     row_result = self.explain_row(
#     267         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     269     )
#     270     values.append(row_result.get("values", None))
#     271     output_indices.append(row_result.get("output_indices", None))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\explainers\_permutation.py:92, in Permutation.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#      88 """ Explains a single row and returns the tuple (row_values, row_expected_values, row_mask_shapes).
#      89 """
#      91 # build a masked version of the model for the current input sample
# ---> 92 fm = MaskedModel(self.model, self.masker, self.link, self.linearize_link, *row_args)
#      94 # by default we run 10 permutations forward and backward
#      95 if max_evals == "auto":
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_masked_model.py:28, in MaskedModel.__init__(self, model, masker, link, linearize_link, *args)
#      26 # if the masker supports it, save what positions vary from the background
#      27 if callable(getattr(self.masker, "invariants", None)):
# ---> 28     self._variants = ~self.masker.invariants(*args)
#      29     self._variants_column_sums = self._variants.sum(0)
#      30     self._variants_row_inds = [
#      31         self._variants[:,i] for i in range(self._variants.shape[1])
#      32     ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\maskers\_tabular.py:145, in Tabular.invariants(self, x)
#     143 # make sure we got valid data
#     144 if x.shape != self.data.shape[1:]:
# --> 145     raise DimensionError(
#     146         "The passed data does not match the background shape expected by the masker! The data of shape " + \
#     147         str(x.shape) + " was passed while the masker expected data of shape " + str(self.data.shape[1:]) + "."
#     148     )
#     150 return np.isclose(x, self.data)
#
# DimensionError: The passed data does not match the background shape expected by the masker! The data of shape (34,) was passed while the masker expected data of shape (35,).

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# ## MLR Ordinary Least Squares

# %%
X_train = sm.add_constant(X_train) # adding a constant

model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_train)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        layoff_category   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     11.78
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):           1.56e-55
# Time:                        18:08:41   Log-Likelihood:                -9584.8
# No. Observations:                7980   AIC:                         1.923e+04
# Df Residuals:                    7949   BIC:                         1.945e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                      86.6705     19.334      4.483      0.000      48.772     124.569
# Open                                                        0.0446      0.022      1.986      0.047       0.001       0.089
# High                                                       -0.0325      0.020     -1.657      0.098      -0.071       0.006
# Low                                                        -0.0254      0.019     -1.322      0.186      -0.063       0.012
# Close                                                       0.0127      0.021      0.613      0.540      -0.028       0.054
# Volume                                                   4.536e-10    6.2e-10      0.731      0.465   -7.62e-10    1.67e-09
# CPI                                                         0.0229      0.015      1.555      0.120      -0.006       0.052
# PPI                                                        -0.0059      0.002     -3.059      0.002      -0.010      -0.002
# GDP                                                        -0.0440      0.019     -2.371      0.018      -0.080      -0.008
# unemployment_rate                                           0.0750      0.020      3.751      0.000       0.036       0.114
# job_nonfam                                               5.989e-05   5.89e-05      1.017      0.309   -5.56e-05       0.000
# job_IT                                                      0.0012      0.001      1.802      0.072      -0.000       0.003
# job_service                                                -0.0005      0.000     -2.207      0.027      -0.001   -5.06e-05
# job_retail                                                  0.0003      0.000      1.801      0.072   -2.92e-05       0.001
# job_education_health                                        0.0007      0.000      2.912      0.004       0.000       0.001
# fed_rate                                                    0.0294      0.018      1.623      0.105      -0.006       0.065
# PPI_chg                                                     0.0411      0.012      3.314      0.001       0.017       0.065
# PPI_CPI                                                     0.0182      0.009      2.132      0.033       0.001       0.035
# year                                                       -0.0471      0.011     -4.351      0.000      -0.068      -0.026
# month                                                       0.0046      0.003      1.378      0.168      -0.002       0.011
# Hires_jolts                                                 0.0626      0.050      1.258      0.208      -0.035       0.160
# Quits_jolts                                                -0.0206      0.086     -0.241      0.810      -0.189       0.147
# Layoffs_jolts                                               0.0611      0.010      5.984      0.000       0.041       0.081
# Hire_quite_jolts                                            0.0832      0.038      2.201      0.028       0.009       0.157
# Job_seekers_ratio                                          -0.0816      0.024     -3.389      0.001      -0.129      -0.034
# Price Volatility                                           -0.0070      0.007     -0.970      0.332      -0.021       0.007
# Industry_Consumer Discretionary Select Sector SPDR Fund     9.7114      2.149      4.520      0.000       5.499      13.923
# Industry_Consumer Staples Select Sector SPDR FundÂ          9.6433      2.149      4.487      0.000       5.430      13.857
# Industry_Energy Select Sector SPDR Fund                     9.7154      2.151      4.516      0.000       5.498      13.932
# Industry_Financial Select Sector SPDR Fund                  9.4035      2.148      4.377      0.000       5.192      13.615
# Industry_Health Care Select Sector SPDR FundÂ               9.6158      2.147      4.478      0.000       5.407      13.825
# Industry_Industrial Select Sector SPDR Fund                 9.7801      2.147      4.555      0.000       5.571      13.989
# Industry_Materials Select Sector SPDR Fund                  9.5578      2.148      4.449      0.000       5.346      13.769
# Industry_Technology Select Sector SPDR Fund                 9.6583      2.149      4.494      0.000       5.445      13.871
# Industry_Utilities Select Sector SPDR Fund                  9.5850      2.149      4.461      0.000       5.373      13.797
# ==============================================================================
# Omnibus:                    81194.148   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              645.269
# Skew:                           0.008   Prob(JB):                    7.61e-141
# Kurtosis:                       1.607   Cond. No.                     1.14e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.1e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # GaussianNB

# %%
gnb = GaussianNB()
preds = gnb.fit(X_train, y_train).predict(X_test)

# %%
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != preds).sum()))
# Out:
# Number of mislabeled points out of a total 1995 points : 1214

# %%
accuray = accuracy_score(preds, y_test)
f1 = f1_score(preds, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.39147869674185465
# F1 Score: 0.40454136230479754

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

modelRF = SelectFromModel(rfc).fit(X_train, y_train)

X_train_newRF = modelRF.transform(X_train)
feature_names = X_train.columns[modelRF.get_support()]
X_test_newRF = X_test[feature_names]

rfc_new = RandomForestClassifier().fit(X_train_newRF, y_train)

predsRF = rfc_new.predict(X_test_newRF)

accuracy_score(predsRF, y_test)
# Out:
# X has feature names, but RandomForestClassifier was fitted without feature names
# 0.5147869674185463

# %% [markdown]
# ## Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()

modelETC = SelectFromModel(etc).fit(X_train, y_train)

X_train_newETC = modelETC.transform(X_train)
feature_names = X_train.columns[modelETC.get_support()]
X_test_newETC = X_test[feature_names]

etc_new = ExtraTreesClassifier().fit(X_train_newETC, y_train)

predsETC = etc_new.predict(X_test_newETC)

accuracy_score(predsETC, y_test)
# Out:
# X has feature names, but ExtraTreesClassifier was fitted without feature names
# 0.48471177944862154

# %% [markdown]
# ## Neural Net

# %%
from sklearn.neural_network import MLPClassifier


mlp = MLPClassifier(alpha=0.1, max_iter=1000)

modelMLP = SelectFromModel(mlp).fit(X_train, y_train)

X_train_newMLP = modelMLP.transform(X_train)
feature_names = X_train.columns[modelMLP.get_support()]
X_test_newMLP = X_test[feature_names]

mlp_new = MLPClassifier(alpha=0.1, max_iter=1000).fit(X_train_newMLP, y_train)

predsMLP = mlp_new.predict(X_test_newMLP)

accuracy_score(predsMLP, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [20], line 8
#       4 mlp = MLPClassifier(alpha=0.1, max_iter=1000)
#       6 modelMLP = SelectFromModel(mlp).fit(X_train, y_train)
# ----> 8 X_train_newMLP = modelMLP.transform(X_train)
#       9 feature_names = X_train.columns[modelMLP.get_support()]
#      10 X_test_newMLP = X_test[feature_names]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_base.py:90, in SelectorMixin.transform(self, X)
#      81 # note: we use _safe_tags instead of _get_tags because this is a
#      82 # public Mixin.
#      83 X = self._validate_data(
#      84     X,
#      85     dtype=None,
#    (...)
#      88     reset=False,
#      89 )
# ---> 90 return self._transform(X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_base.py:94, in SelectorMixin._transform(self, X)
#      92 def _transform(self, X):
#      93     """Reduce X to the selected features."""
# ---> 94     mask = self.get_support()
#      95     if not mask.any():
#      96         warnings.warn(
#      97             "No features were selected: either the data is"
#      98             " too noisy or the selection test too strict.",
#      99             UserWarning,
#     100         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_base.py:53, in SelectorMixin.get_support(self, indices)
#      33 def get_support(self, indices=False):
#      34     """
#      35     Get a mask, or integer index, of the features selected.
#      36
#    (...)
#      51         values are indices into the input feature vector.
#      52     """
# ---> 53     mask = self._get_support_mask()
#      54     return mask if not indices else np.where(mask)[0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_from_model.py:289, in SelectFromModel._get_support_mask(self)
#     283 elif max_features is not None and not isinstance(max_features, Integral):
#     284     raise ValueError(
#     285         f"`max_features` must be an integer. Got `max_features={max_features}` "
#     286         "instead."
#     287     )
# --> 289 scores = _get_feature_importances(
#     290     estimator=estimator,
#     291     getter=self.importance_getter,
#     292     transform_func="norm",
#     293     norm_order=self.norm_order,
#     294 )
#     295 threshold = _calculate_threshold(estimator, scores, self.threshold)
#     296 if self.max_features is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_base.py:208, in _get_feature_importances(estimator, getter, transform_func, norm_order)
#     206         getter = attrgetter("feature_importances_")
#     207     else:
# --> 208         raise ValueError(
#     209             "when `importance_getter=='auto'`, the underlying "
#     210             f"estimator {estimator.__class__.__name__} should have "
#     211             "`coef_` or `feature_importances_` attribute. Either "
#     212             "pass a fitted estimator to feature selector or call fit "
#     213             "before calling transform."
#     214         )
#     215 else:
#     216     getter = attrgetter(getter)
#
# ValueError: when `importance_getter=='auto'`, the underlying estimator MLPClassifier should have `coef_` or `feature_importances_` attribute. Either pass a fitted estimator to feature selector or call fit before calling transform.

# %% [markdown]
# # SGD

# %%
clf = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3, alpha=1, penalty='l1'))
preds = clf.fit(X_train, y_train).predict(X_test)

# %%
param_grid = {'alpha' : [.001,.01,.1,1,10,100],
              'penalty': ['l2', 'l1', 'elasticnet', None]}

gridsearch = GridSearchCV(SGDClassifier(max_iter=1000, tol=1e-3), param_grid, cv=10).fit(X_train, y_train)
# Out:
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.

# %%
gridsearch.best_params_
# Out:
# {'alpha': 1, 'penalty': 'l1'}

# %%
clf = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3, alpha=1, penalty='l1'))
preds = clf.fit(X_train, y_train).predict(X_test)

# %%
accuray = accuracy_score(preds, y_test)
f1 = f1_score(preds, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.3383458646616541
# F1 Score: 0.5056179775280898

# %%
SGD = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3, alpha=1, penalty='l1'))
modelSGD = SelectFromModel(clf, prefit=True)
X_train_newSGD = modelSGD.transform(X_train)
feature_names = X_train.columns[modelSGD.get_support()]
X_test_newSGD = X_test[feature_names]
SGD0 = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3, alpha=1, penalty='l1')).fit(X_train_newSGD, y_train)
predsSGD = SGD0.predict(X_test_newSGD)
accuracy_score(predsSGD,y_test)

# %% [markdown]
# # Feature Selection

# %%
model0 = SelectFromModel(MLR, prefit=True)

# %%
X_train_new = model0.transform(X_train)
# Out:
# X has feature names, but SelectFromModel was fitted without feature names

# %%
feature_names = X_train.columns[model0.get_support()]

# %%
print('Feature Names \n',feature_names)
# Out:
# Feature Names
#  Index(['Open', 'GDP', 'unemployment_rate', 'year', 'Hires_jolts',
#        'Layoffs_jolts', 'Hire_quite_jolts', 'Job_seekers_ratio',
#        'Industry_Consumer Discretionary Select Sector SPDR Fund',
#        'Industry_Energy Select Sector SPDR Fund',
#        'Industry_Financial Select Sector SPDR Fund',
#        'Industry_Industrial Select Sector SPDR Fund',
#        'Industry_Materials Select Sector SPDR Fund',
#        'Industry_Utilities Select Sector SPDR Fund'],
#       dtype='object')

# %%
X_test_new = X_test[feature_names]

# %%
X_test_new = X_test[['Open','GDP','unemployment_rate', 'year', 'Hires_jolts',
       'Layoffs_jolts', 'Hire_quite_jolts', 'Job_seekers_ratio', 'Industry_Consumer Discretionary Select Sector SPDR Fund', 'Industry_Energy Select Sector SPDR Fund','Industry_Financial Select Sector SPDR Fund','Industry_Industrial Select Sector SPDR Fund','Industry_Materials Select Sector SPDR Fund','Industry_Utilities Select Sector SPDR Fund']]

# %%
MLR0 = LinearRegression().fit(X_train_new, y_train)
preds = MLR0.predict(X_test_new)
# Out:
# X has feature names, but LinearRegression was fitted without feature names

# %%
preds = np.round(preds)
# Out:
# array([2., 2., 2., ..., 2., 2., 2.])

# %%
y_test = y_test.cat.codes.astype(np.float64)

# %%
accuracy_score(preds,y_test)
# Out:
# 0.3107769423558897
